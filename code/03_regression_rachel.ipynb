# %%
import pandas as pd
import re
import numpy as np
import statsmodels.formula.api as smf
path_dist   = r"../data/input/abortion_distance_raw.csv"
path_births = r"../data/input/oklahoma_births-by-county_by-race_2010-2024.csv"

dist_raw   = pd.read_csv(path_dist)
births_raw = pd.read_csv(path_births)

# %%
births_raw.head(30)
# Out:
#    Search Characteristic                   Values Selected Unnamed: 2  \
# 0              Year 2010                               NaN        NaN
# 1                    NaN                               NaN     Births
# 2    County of Residence                     Mother's Race        NaN
# 3                UNKNOWN                             White         18
# 4                    NaN         Black or African American          .
# 5                    NaN  American Indian or Alaska Native          .
# 6                    NaN                           Unknown          .
# 7                  Adair                             White         63
# 8                    NaN         Black or African American          .
# 9                    NaN  American Indian or Alaska Native        169
# 10                   NaN                             Asian          .
# 11                   NaN                             Other          .
# 12                   NaN                           Unknown        131
# 13                   NaN                More than one race          5
# 14               Alfalfa                             White         42
# 15                   NaN  American Indian or Alaska Native          .
# 16                   NaN                             Other          .
# 17                   NaN                More than one race          .
# 18                 Atoka                             White        123
# 19                   NaN         Black or African American          7
# 20                   NaN  American Indian or Alaska Native         37
# 21                   NaN                More than one race          .
# 22                Beaver                             White         63
# 23                   NaN         Black or African American          .
# 24                   NaN                             Other          .
# 25               Beckham                             White        297
# 26                   NaN         Black or African American          7
# 27                   NaN  American Indian or Alaska Native         13
# 28                   NaN                             Asian          .
# 29                   NaN                             Other          .
#
#     Unnamed: 3  Unnamed: 4
# 0          NaN         NaN
# 1   Population  Birth Rate
# 2          NaN         NaN
# 3            .           .
# 4            .           .
# 5            .           .
# 6            .           .
# 7        10038         6.3
# 8           69           .
# 9        10210        16.6
# 10         136           .
# 11           .           .
# 12           .           .
# 13        2306         2.2
# 14        5101         8.2
# 15         174           .
# 16           .           .
# 17         102           .
# 18       10596        11.6
# 19         521        13.4
# 20        2030        18.2
# 21        1006           .
# 22        5369        11.7
# 23          45           .
# 24           .           .
# 25       19749        15.0
# 26         902         7.8
# 27         682        19.1
# 28         204           .
# 29           .           .

# %%
dist = dist_raw.copy()
# Option A: use the state column
ok = dist[dist["origin_state"] == "OK"].copy()
ok["county"] = (
    ok["origin_county_name"]
        .str.replace(r"\s*\(.*\)", "", regex=True)
        .str.replace(" County", "", regex=False)    
        .str.strip()
)
dist_df = ok[['year','month',"origin_fips_code", "county", "origin_state", "origin_population", 'distance_origintodest']]

dist_df
# Out:
#         year  month  origin_fips_code    county origin_state  \
# 426200  2010      8             40001     Adair           OK
# 426201  2010      9             40001     Adair           OK
# 426202  2010     10             40001     Adair           OK
# 426203  2010     11             40001     Adair           OK
# 426204  2010     12             40001     Adair           OK
# ...      ...    ...               ...       ...          ...
# 441595  2018      1             40153  Woodward           OK
# 441596  2018      2             40153  Woodward           OK
# 441597  2018      3             40153  Woodward           OK
# 441598  2018      4             40153  Woodward           OK
# 441599  2018      5             40153  Woodward           OK
#
#         origin_population  distance_origintodest
# 426200             4285.0              44.282017
# 426201             4285.0              44.282017
# 426202             4285.0              44.282017
# 426203             4285.0              44.282017
# 426204             4285.0              44.282017
# ...                   ...                    ...
# 441595             3669.0             141.880800
# 441596             3669.0             141.880800
# 441597             3669.0             141.880800
# 441598             3669.0             141.880800
# 441599             3669.0             141.880800
#
# [15400 rows x 7 columns]

# %%
import pandas as pd
import numpy as np

df = births_raw.copy()
df.columns = ["col0", "col1", "col2", "col3", "col4"]
is_year_row = df["col0"].astype(str).str.contains("Year", na=False)

df.loc[is_year_row, "year"] = (
    df.loc[is_year_row, "col0"]
      .astype(str)
      .str.extract(r"(\d{4})")[0]
      .astype("Int64")
)
df["year"] = df["year"].ffill()
df = df[df["year"].notna()].copy()
df = df[~df["col1"].eq("Mother's Race")].copy()
df = df[~is_year_row].copy()

df["county"] = df["col0"].where(df["col0"].notna()).ffill()

county_filter = (
    df["county"].fillna("").str.fullmatch("Unknown", case=False) |
    df["county"].fillna("").str.contains("UNKNOWN COUNTY", case=False)
)
df = df[~county_filter].copy()
df["race"] = df["col1"]

for c in ["col2", "col3", "col4"]:
    df[c] = pd.to_numeric(df[c].replace(".", np.nan), errors="coerce")

df = df.rename(columns={
    "col2": "births",
    "col3": "population",
    "col4": "birth_rate",
})
valid = df["births"].notna() | df["population"].notna()
df = df[valid].copy()

df.loc[df["births"].isna() & df["population"].notna(), "births"] = 0

needs_rate = df["birth_rate"].isna() & df["population"].gt(0)
df.loc[needs_rate, "birth_rate"] = (
    df.loc[needs_rate, "births"] / df.loc[needs_rate, "population"] * 1000
)
births_df = df[["year", "county", "race", "births", "population", "birth_rate"]].reset_index(drop=True)
births_df.head(40)
# Out:
# /var/folders/7w/t6w_w15x5nb5xfxzxr9z18g80000gn/T/ipykernel_67498/3958812945.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df[~is_year_row].copy()
#     year    county                              race  births  population  \
# 0   2010     Adair                             White    63.0     10038.0
# 1   2010     Adair         Black or African American     0.0        69.0
# 2   2010     Adair  American Indian or Alaska Native   169.0     10210.0
# 3   2010     Adair                             Asian     0.0       136.0
# 4   2010     Adair                           Unknown   131.0         NaN
# 5   2010     Adair                More than one race     5.0      2306.0
# 6   2010   Alfalfa                             White    42.0      5101.0
# 7   2010   Alfalfa  American Indian or Alaska Native     0.0       174.0
# 8   2010   Alfalfa                More than one race     0.0       102.0
# 9   2010     Atoka                             White   123.0     10596.0
# 10  2010     Atoka         Black or African American     7.0       521.0
# 11  2010     Atoka  American Indian or Alaska Native    37.0      2030.0
# 12  2010     Atoka                More than one race     0.0      1006.0
# 13  2010    Beaver                             White    63.0      5369.0
# 14  2010    Beaver         Black or African American     0.0        45.0
# 15  2010   Beckham                             White   297.0     19749.0
# 16  2010   Beckham         Black or African American     7.0       902.0
# 17  2010   Beckham  American Indian or Alaska Native    13.0       682.0
# 18  2010   Beckham                             Asian     0.0       204.0
# 19  2010   Beckham                More than one race     9.0       517.0
# 20  2010    Blaine                             White   106.0      8188.0
# 21  2010    Blaine         Black or African American     0.0       310.0
# 22  2010    Blaine  American Indian or Alaska Native    26.0       997.0
# 23  2010    Blaine                             Other     7.0         NaN
# 24  2010    Blaine                More than one race    12.0       387.0
# 25  2010     Bryan                             White   450.0     33029.0
# 26  2010     Bryan         Black or African American     9.0       678.0
# 27  2010     Bryan  American Indian or Alaska Native   126.0      5665.0
# 28  2010     Bryan                             Asian     0.0       225.0
# 29  2010     Bryan                             Other    10.0         NaN
# 30  2010     Bryan                More than one race    12.0      2970.0
# 31  2010     Caddo                             White   233.0     19446.0
# 32  2010     Caddo         Black or African American     9.0       835.0
# 33  2010     Caddo  American Indian or Alaska Native   170.0      7603.0
# 34  2010     Caddo                             Other    17.0         NaN
# 35  2010     Caddo                More than one race    32.0      1736.0
# 36  2010  Canadian                             White  1272.0     99483.0
# 37  2010  Canadian         Black or African American    33.0      3077.0
# 38  2010  Canadian  American Indian or Alaska Native    96.0      5838.0
# 39  2010  Canadian                             Asian    46.0      3562.0
#
#     birth_rate
# 0          6.3
# 1          0.0
# 2         16.6
# 3          0.0
# 4          NaN
# 5          2.2
# 6          8.2
# 7          0.0
# 8          0.0
# 9         11.6
# 10        13.4
# 11        18.2
# 12         0.0
# 13        11.7
# 14         0.0
# 15        15.0
# 16         7.8
# 17        19.1
# 18         0.0
# 19        17.4
# 20        12.9
# 21         0.0
# 22        26.1
# 23         NaN
# 24        31.0
# 25        13.6
# 26        13.3
# 27        22.2
# 28         0.0
# 29         NaN
# 30         4.0
# 31        12.0
# 32        10.8
# 33        22.4
# 34         NaN
# 35        18.4
# 36        12.8
# 37        10.7
# 38        16.4
# 39        12.9

# %%
births_df["county"] = births_df["county"].str.strip().str.lower()
dist_df["county"] = dist_df["county"].str.strip().str.lower()
# Out:
# /var/folders/7w/t6w_w15x5nb5xfxzxr9z18g80000gn/T/ipykernel_67498/168091081.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dist_df["county"] = dist_df["county"].str.strip().str.lower()

# %%
dist_year = (
    dist_df
    .groupby(["year", "county"], as_index=False)
    .agg({
        "distance_origintodest": "mean",  
        "origin_fips_code": "first",      
        "origin_state": "first",
        "origin_population": "first"      
    })
)

dist_year.rename(
    columns={
        "distance_origintodest": "dist_mean",
        "origin_population": "county_pop_dist"
    },
    inplace=True
)

births_merged = births_df.merge(
    dist_year[["year", "county", "origin_fips_code", "dist_mean"]],
    on=["year", "county"],
    how="left"
)

births_merged.head(20)
# Out:
#     year   county                              race  births  population  \
# 0   2010    adair                             White    63.0     10038.0
# 1   2010    adair         Black or African American     0.0        69.0
# 2   2010    adair  American Indian or Alaska Native   169.0     10210.0
# 3   2010    adair                             Asian     0.0       136.0
# 4   2010    adair                           Unknown   131.0         NaN
# 5   2010    adair                More than one race     5.0      2306.0
# 6   2010  alfalfa                             White    42.0      5101.0
# 7   2010  alfalfa  American Indian or Alaska Native     0.0       174.0
# 8   2010  alfalfa                More than one race     0.0       102.0
# 9   2010    atoka                             White   123.0     10596.0
# 10  2010    atoka         Black or African American     7.0       521.0
# 11  2010    atoka  American Indian or Alaska Native    37.0      2030.0
# 12  2010    atoka                More than one race     0.0      1006.0
# 13  2010   beaver                             White    63.0      5369.0
# 14  2010   beaver         Black or African American     0.0        45.0
# 15  2010  beckham                             White   297.0     19749.0
# 16  2010  beckham         Black or African American     7.0       902.0
# 17  2010  beckham  American Indian or Alaska Native    13.0       682.0
# 18  2010  beckham                             Asian     0.0       204.0
# 19  2010  beckham                More than one race     9.0       517.0
#
#     birth_rate  origin_fips_code   dist_mean
# 0          6.3             40001   41.352927
# 1          0.0             40001   41.352927
# 2         16.6             40001   41.352927
# 3          0.0             40001   41.352927
# 4          NaN             40001   41.352927
# 5          2.2             40001   41.352927
# 6          8.2             40003  117.173210
# 7          0.0             40003  117.173210
# 8          0.0             40003  117.173210
# 9         11.6             40005  116.996120
# 10        13.4             40005  116.996120
# 11        18.2             40005  116.996120
# 12         0.0             40005  116.996120
# 13        11.7             40007  230.243500
# 14         0.0             40007  230.243500
# 15        15.0             40009  122.553670
# 16         7.8             40009  122.553670
# 17        19.1             40009  122.553670
# 18         0.0             40009  122.553670
# 19        17.4             40009  122.553670

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import StrMethodFormatter

# Set theme
sns.set_theme(style="whitegrid", palette="pastel")

# Ensure year is string so x-axis shows actual years
births_merged['year'] = births_merged['year'].astype(str)

# Aggregate mean distance by year
grouped = births_merged.groupby("year")["dist_mean"].mean().reset_index()

# Create the point plot
g = sns.pointplot(
    data=grouped,
    x="year",
    y="dist_mean",
    color="green",
    marker="o",
    linestyles="-"
)

# Expand y-axis and start at 0
ymax = grouped["dist_mean"].max()
g.set_ylim(0, ymax * 1.15)  # 15% headroom

# Title
g.set_title("Average distance to the nearest abortion facility doubled after ban", fontsize=14, weight='bold')

# Axis labels
g.set_xlabel("Year", fontsize=12)
g.set_ylabel("Average Distance (miles)", fontsize=12)

# Rotate x-ticks so years are readable
g.set_xticklabels(g.get_xticklabels(), rotation=45)

# Add vertical line for 2022 abortion ban
plt.axvline(x=grouped[grouped['year']=="2022"].index[0], linestyle='--', color='lightgrey', linewidth=1.5)
g.text(
    grouped[grouped['year']=="2022"].index[0] + 0.2,
    ymax * 0.75,
    "2022 Abortion Ban",
    rotation=90,
    color='black',
    va='top',
    ha='left'
)

# Format y-axis with commas
g.yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))

# Remove top/right spines for cleaner look
sns.despine(left=True, bottom=True)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/7w/t6w_w15x5nb5xfxzxr9z18g80000gn/T/ipykernel_67498/1642775371.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(g.get_xticklabels(), rotation=45)

# %%
county_year = (
    births_df
    .groupby(["year", "county"], as_index=False)
    .agg({
        "births": "sum",
        "population": "sum"
    })
)
county_year["birth_rate"] = (county_year["births"] / county_year["population"]) * 1000
county_year["county"] = county_year["county"].str.strip().str.lower()
dist_year["county"]    = dist_year["county"].str.strip().str.lower()
final_df = county_year.merge(
    dist_year[["year", "county", "dist_mean", "origin_fips_code"]],
    on=["year", "county"],
    how="left"
)

final_df["post_ban"] = (final_df["year"] >= 2022).astype(int)

final_df
# Out:
#       year      county  births  population  birth_rate   dist_mean  \
# 0     2010       adair   368.0     22759.0   16.169427   41.352927
# 1     2010     alfalfa    42.0      5377.0    7.811047  117.173210
# 2     2010       atoka   167.0     14153.0   11.799618  116.996120
# 3     2010      beaver    63.0      5414.0   11.636498  230.243500
# 4     2010     beckham   326.0     22054.0   14.781899  122.553670
# ...    ...         ...     ...         ...         ...         ...
# 1150  2024     wagoner   929.0     91257.0   10.180041  179.042720
# 1151  2024  washington   580.0     54016.0   10.737559  130.514463
# 1152  2024     washita   115.0     10758.0   10.689719  264.817230
# 1153  2024       woods    59.0      8291.0    7.116150  138.861540
# 1154  2024    woodward   228.0     19970.0   11.417126  209.295210
#
#       origin_fips_code  post_ban
# 0                40001         0
# 1                40003         0
# 2                40005         0
# 3                40007         0
# 4                40009         0
# ...                ...       ...
# 1150             40145         1
# 1151             40147         1
# 1152             40149         1
# 1153             40151         1
# 1154             40153         1
#
# [1155 rows x 8 columns]

# %%
import statsmodels.formula.api as smf

reg_df = final_df.dropna(subset=["birth_rate", "dist_mean"]).copy()
reg_df["post_ban"] = (reg_df["year"] >= 2022).astype("int64")
reg_df["year_cat"] = reg_df["year"].astype(str)
reg_df["dist_mean"] = reg_df["dist_mean"].astype("float64")
reg_df["birth_rate"] = reg_df["birth_rate"].astype("float64")

# %%
reg_df
# Out:
#       year      county  births  population  birth_rate   dist_mean  \
# 0     2010       adair   368.0     22759.0   16.169427   41.352927
# 1     2010     alfalfa    42.0      5377.0    7.811047  117.173210
# 2     2010       atoka   167.0     14153.0   11.799618  116.996120
# 3     2010      beaver    63.0      5414.0   11.636498  230.243500
# 4     2010     beckham   326.0     22054.0   14.781899  122.553670
# ...    ...         ...     ...         ...         ...         ...
# 1150  2024     wagoner   929.0     91257.0   10.180041  179.042720
# 1151  2024  washington   580.0     54016.0   10.737559  130.514463
# 1152  2024     washita   115.0     10758.0   10.689719  264.817230
# 1153  2024       woods    59.0      8291.0    7.116150  138.861540
# 1154  2024    woodward   228.0     19970.0   11.417126  209.295210
#
#       origin_fips_code  post_ban year_cat
# 0                40001         0     2010
# 1                40003         0     2010
# 2                40005         0     2010
# 3                40007         0     2010
# 4                40009         0     2010
# ...                ...       ...      ...
# 1150             40145         1     2024
# 1151             40147         1     2024
# 1152             40149         1     2024
# 1153             40151         1     2024
# 1154             40153         1     2024
#
# [1155 rows x 9 columns]

# %%
model_pp = smf.ols(
    "birth_rate ~ dist_mean * post_ban",
    data=reg_df
).fit(cov_type="HC3")

print(model_pp.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             birth_rate   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     24.43
# Date:                Tue, 02 Dec 2025   Prob (F-statistic):           2.51e-15
# Time:                        15:35:07   Log-Likelihood:                -2373.8
# No. Observations:                1155   AIC:                             4756.
# Df Residuals:                    1151   BIC:                             4776.
# Df Model:                           3
# Covariance Type:                  HC3
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             11.9790      0.137     87.256      0.000      11.710      12.248
# dist_mean              0.0009      0.002      0.593      0.553      -0.002       0.004
# post_ban              -1.9800      0.401     -4.943      0.000      -2.765      -1.195
# dist_mean:post_ban     0.0043      0.002      1.799      0.072      -0.000       0.009
# ==============================================================================
# Omnibus:                       17.991   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.474
# Skew:                           0.291   Prob(JB):                     9.73e-05
# Kurtosis:                       3.210   Cond. No.                     1.20e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large, 1.2e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import statsmodels.formula.api as smf

reg_df = final_df.dropna(subset=["birth_rate"]).copy()

reg_df["post_ban"] = (reg_df["year"] >= 2022).astype(int)

model_simple = smf.ols(
    formula="birth_rate ~ post_ban",
    data=reg_df
).fit(cov_type="HC3")

print(model_simple.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             birth_rate   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     59.76
# Date:                Tue, 02 Dec 2025   Prob (F-statistic):           2.32e-14
# Time:                        15:35:07   Log-Likelihood:                -2377.8
# No. Observations:                1155   AIC:                             4760.
# Df Residuals:                    1153   BIC:                             4770.
# Df Model:                           1
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     12.0634      0.064    188.304      0.000      11.938      12.189
# post_ban      -0.9929      0.128     -7.730      0.000      -1.245      -0.741
# ==============================================================================
# Omnibus:                       21.958   Durbin-Watson:                   2.045
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.852
# Skew:                           0.322   Prob(JB):                     1.09e-05
# Kurtosis:                       3.245   Cond. No.                         2.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
missing_in_dist = (
    births_df[["year", "county"]]
    .drop_duplicates()
    .merge(dist_year[["year", "county"]], on=["year", "county"], how="left", indicator=True)
)

missing_in_dist[missing_in_dist["_merge"] == "left_only"]
# Out:
# Empty DataFrame
# Columns: [year, county, _merge]
# Index: []

# %%
reg_df
# Out:
#       year      county  births  population  birth_rate   dist_mean  \
# 0     2010       adair   368.0     22759.0   16.169427   41.352927
# 1     2010     alfalfa    42.0      5377.0    7.811047  117.173210
# 2     2010       atoka   167.0     14153.0   11.799618  116.996120
# 3     2010      beaver    63.0      5414.0   11.636498  230.243500
# 4     2010     beckham   326.0     22054.0   14.781899  122.553670
# ...    ...         ...     ...         ...         ...         ...
# 1150  2024     wagoner   929.0     91257.0   10.180041  179.042720
# 1151  2024  washington   580.0     54016.0   10.737559  130.514463
# 1152  2024     washita   115.0     10758.0   10.689719  264.817230
# 1153  2024       woods    59.0      8291.0    7.116150  138.861540
# 1154  2024    woodward   228.0     19970.0   11.417126  209.295210
#
#       origin_fips_code  post_ban year_cat
# 0                40001         0     2010
# 1                40003         0     2010
# 2                40005         0     2010
# 3                40007         0     2010
# 4                40009         0     2010
# ...                ...       ...      ...
# 1150             40145         1     2024
# 1151             40147         1     2024
# 1152             40149         1     2024
# 1153             40151         1     2024
# 1154             40153         1     2024
#
# [1155 rows x 9 columns]

# %%
formula = "birth_rate ~ dist_mean * post_ban + C(county) + C(year_cat)"

model_fe = smf.ols(
    formula=formula,
    data=reg_df
).fit(
    cov_type="cluster",
    cov_kwds={"groups": reg_df["county"]}
)

print(model_fe.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             birth_rate   R-squared:                       0.685
# Model:                            OLS   Adj. R-squared:                  0.658
# Method:                 Least Squares   F-statistic:                     5349.
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):          4.79e-109
# Time:                        13:06:37   Log-Likelihood:                -1735.3
# No. Observations:                1155   AIC:                             3657.
# Df Residuals:                    1062   BIC:                             4126.
# Df Model:                          92
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    14.7064      0.176     83.647      0.000      14.362      15.051
# C(county)[T.alfalfa]         -5.1331      0.074    -69.757      0.000      -5.277      -4.989
# C(county)[T.atoka]           -3.4198      0.080    -42.862      0.000      -3.576      -3.263
# C(county)[T.beaver]          -4.3016      0.221    -19.460      0.000      -4.735      -3.868
# C(county)[T.beckham]         -0.9307      0.087    -10.709      0.000      -1.101      -0.760
# C(county)[T.blaine]          -0.6746      0.023    -29.029      0.000      -0.720      -0.629
# C(county)[T.bryan]           -1.2795      0.044    -28.757      0.000      -1.367      -1.192
# C(county)[T.caddo]           -1.2628      0.010   -124.838      0.000      -1.283      -1.243
# C(county)[T.canadian]        -1.0893      0.061    -17.877      0.000      -1.209      -0.970
# C(county)[T.carter]          -0.8663      0.029    -30.005      0.000      -0.923      -0.810
# C(county)[T.cherokee]        -2.2831      0.009   -242.534      0.000      -2.302      -2.265
# C(county)[T.choctaw]         -1.4819      0.104    -14.280      0.000      -1.685      -1.278
# C(county)[T.cimarron]        -3.5101      0.241    -14.544      0.000      -3.983      -3.037
# C(county)[T.cleveland]       -3.5340      0.073    -48.227      0.000      -3.678      -3.390
# C(county)[T.coal]            -2.0148      0.062    -32.258      0.000      -2.137      -1.892
# C(county)[T.comanche]         0.2605      0.026      9.841      0.000       0.209       0.312
# C(county)[T.cotton]          -3.8481      0.063    -60.979      0.000      -3.972      -3.724
# C(county)[T.craig]           -3.1975      0.021   -150.560      0.000      -3.239      -3.156
# C(county)[T.creek]           -2.1643      0.056    -38.731      0.000      -2.274      -2.055
# C(county)[T.custer]          -0.2028      0.039     -5.154      0.000      -0.280      -0.126
# C(county)[T.delaware]        -4.2877      0.021   -199.574      0.000      -4.330      -4.246
# C(county)[T.dewey]           -2.9208      0.081    -36.124      0.000      -3.079      -2.762
# C(county)[T.ellis]           -4.5401      0.134    -33.778      0.000      -4.804      -4.277
# C(county)[T.garfield]         0.2202      0.048      4.577      0.000       0.126       0.314
# C(county)[T.garvin]          -1.2517      0.029    -43.798      0.000      -1.308      -1.196
# C(county)[T.grady]           -3.1910      0.038    -83.243      0.000      -3.266      -3.116
# C(county)[T.grant]           -3.7625      0.059    -63.939      0.000      -3.878      -3.647
# C(county)[T.greer]           -5.0218      0.132    -38.155      0.000      -5.280      -4.764
# C(county)[T.harmon]          -3.2286      0.145    -22.338      0.000      -3.512      -2.945
# C(county)[T.harper]          -3.0249      0.154    -19.636      0.000      -3.327      -2.723
# C(county)[T.haskell]         -2.5014      0.053    -47.448      0.000      -2.605      -2.398
# C(county)[T.hughes]          -3.2013      0.021   -155.011      0.000      -3.242      -3.161
# C(county)[T.jackson]          0.7928      0.099      8.002      0.000       0.599       0.987
# C(county)[T.jefferson]       -3.5372      0.069    -51.572      0.000      -3.672      -3.403
# C(county)[T.johnston]        -2.9770      0.079    -37.687      0.000      -3.132      -2.822
# C(county)[T.kay]             -1.1683      0.059    -19.728      0.000      -1.284      -1.052
# C(county)[T.kingfisher]      -2.0277      0.037    -54.837      0.000      -2.100      -1.955
# C(county)[T.kiowa]           -2.9756      0.097    -30.691      0.000      -3.166      -2.786
# C(county)[T.latimer]         -3.1901      0.098    -32.708      0.000      -3.381      -2.999
# C(county)[T.le flore]        -1.7279      0.062    -27.765      0.000      -1.850      -1.606
# C(county)[T.lincoln]         -3.2342      0.026   -124.583      0.000      -3.285      -3.183
# C(county)[T.logan]           -3.0298      0.058    -52.191      0.000      -3.144      -2.916
# C(county)[T.love]            -2.0433      0.047    -43.672      0.000      -2.135      -1.952
# C(county)[T.major]           -2.3724      0.056    -42.282      0.000      -2.482      -2.262
# C(county)[T.marshall]        -2.7547      0.060    -46.078      0.000      -2.872      -2.637
# C(county)[T.mayes]           -2.3838      0.025    -95.971      0.000      -2.433      -2.335
# C(county)[T.mcclain]         -2.7325      0.066    -41.509      0.000      -2.861      -2.603
# C(county)[T.mccurtain]       -0.6171      0.147     -4.189      0.000      -0.906      -0.328
# C(county)[T.mcintosh]        -4.1216      0.017   -236.914      0.000      -4.156      -4.087
# C(county)[T.murray]          -3.0932      0.009   -352.161      0.000      -3.110      -3.076
# C(county)[T.muskogee]        -1.2169      0.017    -71.940      0.000      -1.250      -1.184
# C(county)[T.noble]           -3.4165      0.050    -68.985      0.000      -3.514      -3.319
# C(county)[T.nowata]          -2.5512      0.038    -66.409      0.000      -2.626      -2.476
# C(county)[T.okfuskee]        -1.6819      0.018    -93.538      0.000      -1.717      -1.647
# C(county)[T.oklahoma]         1.1837      0.077     15.381      0.000       1.033       1.335
# C(county)[T.okmulgee]        -1.9384      0.028    -68.588      0.000      -1.994      -1.883
# C(county)[T.osage]           -5.0187      0.039   -127.373      0.000      -5.096      -4.941
# C(county)[T.ottawa]          -0.7540      0.038    -19.672      0.000      -0.829      -0.679
# C(county)[T.pawnee]          -2.5681      0.044    -58.128      0.000      -2.655      -2.482
# C(county)[T.payne]           -3.7171      0.041    -91.434      0.000      -3.797      -3.637
# C(county)[T.pittsburg]       -3.0331      0.056    -54.304      0.000      -3.143      -2.924
# C(county)[T.pontotoc]        -0.7069      0.020    -35.662      0.000      -0.746      -0.668
# C(county)[T.pottawatomie]    -1.7013      0.035    -48.510      0.000      -1.770      -1.633
# C(county)[T.pushmataha]      -3.8367      0.132    -29.146      0.000      -4.095      -3.579
# C(county)[T.roger mills]     -3.2245      0.114    -28.269      0.000      -3.448      -3.001
# C(county)[T.rogers]          -2.8687      0.050    -56.862      0.000      -2.968      -2.770
# C(county)[T.seminole]        -1.3892      0.014   -101.132      0.000      -1.416      -1.362
# C(county)[T.sequoyah]        -1.9448      0.039    -49.429      0.000      -2.022      -1.868
# C(county)[T.stephens]        -2.5432      0.020   -130.256      0.000      -2.582      -2.505
# C(county)[T.texas]            1.4977      0.240      6.247      0.000       1.028       1.968
# C(county)[T.tillman]         -4.1360      0.097    -42.798      0.000      -4.325      -3.947
# C(county)[T.tulsa]            0.2937      0.080      3.661      0.000       0.136       0.451
# C(county)[T.wagoner]         -2.7655      0.054    -51.175      0.000      -2.871      -2.660
# C(county)[T.washington]      -2.1301      0.046    -46.659      0.000      -2.220      -2.041
# C(county)[T.washita]         -2.4310      0.067    -36.202      0.000      -2.563      -2.299
# C(county)[T.woods]           -4.1874      0.104    -40.379      0.000      -4.391      -3.984
# C(county)[T.woodward]        -1.3547      0.109    -12.471      0.000      -1.568      -1.142
# C(year_cat)[T.2011]          -0.4341      0.175     -2.484      0.013      -0.777      -0.092
# C(year_cat)[T.2012]          -0.2751      0.173     -1.588      0.112      -0.615       0.064
# C(year_cat)[T.2013]          -0.0476      0.180     -0.265      0.791      -0.400       0.305
# C(year_cat)[T.2014]          -0.3724      0.187     -1.994      0.046      -0.739      -0.006
# C(year_cat)[T.2015]          -0.4256      0.206     -2.070      0.038      -0.829      -0.023
# C(year_cat)[T.2016]          -0.7663      0.193     -3.966      0.000      -1.145      -0.388
# C(year_cat)[T.2017]          -1.1982      0.196     -6.121      0.000      -1.582      -0.815
# C(year_cat)[T.2018]          -1.1267      0.192     -5.855      0.000      -1.504      -0.750
# C(year_cat)[T.2019]          -1.5078      0.188     -8.041      0.000      -1.875      -1.140
# C(year_cat)[T.2020]          -1.9456      0.207     -9.405      0.000      -2.351      -1.540
# C(year_cat)[T.2021]          -1.4232      0.242     -5.878      0.000      -1.898      -0.949
# C(year_cat)[T.2022]          -0.2524      0.090     -2.808      0.005      -0.429      -0.076
# C(year_cat)[T.2023]          -0.8976      0.162     -5.537      0.000      -1.215      -0.580
# C(year_cat)[T.2024]          -0.9385      0.165     -5.701      0.000      -1.261      -0.616
# dist_mean                     0.0053      0.002      3.516      0.000       0.002       0.008
# post_ban                     -2.0885      0.301     -6.942      0.000      -2.678      -1.499
# dist_mean:post_ban            0.0020      0.002      0.947      0.344      -0.002       0.006
# ==============================================================================
# Omnibus:                       68.623   Durbin-Watson:                   2.086
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              265.401
# Skew:                           0.075   Prob(JB):                     2.34e-58
# Kurtosis:                       5.344   Cond. No.                     6.92e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 5.69e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /opt/anaconda3/lib/python3.13/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 93, but rank is 16
#   warnings.warn('covariance of constraints does not have full '

# %%
reg_df['race'].unique()
# Out:
# ['White', 'Black or African American', 'American Indian or Alaska Native', 'Asian', 'More than one race', 'Native Hawaiian or Other Pacific Islander']
# Categories (6, object): ['American Indian or Alaska Native', 'Asian', 'Black or African American', 'More than one race', 'Native Hawaiian or Other Pacific Islander', 'White']

# %%
births_merged_cleaned = births_merged[~births_merged['race'].isin(['Unknown', 'Other'])]

reg_df = births_merged_cleaned.dropna(subset=["birth_rate", "dist_mean"]).copy()
reg_df["post_ban"] = (reg_df["year"] >= 2022).astype("int64")
reg_df["year_cat"] = reg_df["year"].astype(str)
reg_df["dist_mean"] = reg_df["dist_mean"].astype("float64")
reg_df["birth_rate"] = reg_df["birth_rate"].astype("float64")

reg_df['race'] = reg_df['race'].astype('category')
reg_df['race'] = reg_df['race'].cat.reorder_categories(
    ['White', 'Black or African American', 'Asian', 'American Indian or Alaska Native', 'More than one race', 'Native Hawaiian or Other Pacific Islander'],  # put your desired baseline first
    ordered=False
)

formula = "birth_rate ~ dist_mean * post_ban * race + C(county) + C(year_cat)"

model_fe_race = smf.ols(
    formula=formula,
    data=reg_df
).fit(
    cov_type="cluster",
    cov_kwds={"groups": reg_df["county"]}
)

print(model_fe_race.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             birth_rate   R-squared:                       0.286
# Model:                            OLS   Adj. R-squared:                  0.271
# Method:                 Least Squares   F-statistic:                     2862.
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):          6.26e-106
# Time:                        13:41:40   Log-Likelihood:                -18059.
# No. Observations:                5345   AIC:                         3.634e+04
# Df Residuals:                    5232   BIC:                         3.709e+04
# Df Model:                         112
# Covariance Type:              cluster
# ========================================================================================================================================
#                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                7.0540      0.618     11.411      0.000       5.842       8.266
# race[T.Black or African American]                                       -2.9339      1.399     -2.097      0.036      -5.676      -0.192
# race[T.Asian]                                                           -1.7297      2.001     -0.864      0.387      -5.652       2.193
# race[T.American Indian or Alaska Native]                                 5.4255      1.114      4.869      0.000       3.242       7.609
# race[T.More than one race]                                               6.0531      0.714      8.482      0.000       4.654       7.452
# race[T.Native Hawaiian or Other Pacific Islander]                       -5.6537      4.448     -1.271      0.204     -14.372       3.065
# C(county)[T.alfalfa]                                                    -6.7324      0.353    -19.073      0.000      -7.424      -6.041
# C(county)[T.atoka]                                                       0.3073      0.387      0.795      0.427      -0.450       1.065
# C(county)[T.beaver]                                                     -6.5186      1.096     -5.947      0.000      -8.667      -4.370
# C(county)[T.beckham]                                                     2.3210      0.405      5.730      0.000       1.527       3.115
# C(county)[T.blaine]                                                      5.4622      0.158     34.515      0.000       5.152       5.772
# C(county)[T.bryan]                                                       1.5792      0.364      4.337      0.000       0.866       2.293
# C(county)[T.caddo]                                                       1.0297      0.063     16.411      0.000       0.907       1.153
# C(county)[T.canadian]                                                    3.9955      0.442      9.049      0.000       3.130       4.861
# C(county)[T.carter]                                                      6.6139      0.138     48.000      0.000       6.344       6.884
# C(county)[T.cherokee]                                                    0.5638      0.096      5.868      0.000       0.375       0.752
# C(county)[T.choctaw]                                                     2.2662      0.486      4.665      0.000       1.314       3.218
# C(county)[T.cimarron]                                                   -5.4207      1.323     -4.097      0.000      -8.014      -2.828
# C(county)[T.cleveland]                                                   1.8839      0.561      3.357      0.001       0.784       2.984
# C(county)[T.coal]                                                       -0.9729      0.329     -2.957      0.003      -1.618      -0.328
# C(county)[T.comanche]                                                    6.4336      0.575     11.191      0.000       5.307       7.560
# C(county)[T.cotton]                                                     -0.8463      0.344     -2.458      0.014      -1.521      -0.172
# C(county)[T.craig]                                                       0.3710      0.086      4.325      0.000       0.203       0.539
# C(county)[T.creek]                                                       2.2085      0.360      6.140      0.000       1.504       2.913
# C(county)[T.custer]                                                      4.8185      0.232     20.742      0.000       4.363       5.274
# C(county)[T.delaware]                                                   -0.8681      0.427     -2.032      0.042      -1.705      -0.031
# C(county)[T.dewey]                                                      -0.1535      0.465     -0.330      0.741      -1.065       0.758
# C(county)[T.ellis]                                                      -6.6372      0.695     -9.547      0.000      -8.000      -5.275
# C(county)[T.garfield]                                                    9.3373      0.592     15.783      0.000       8.178      10.497
# C(county)[T.garvin]                                                      1.8710      0.149     12.534      0.000       1.578       2.164
# C(county)[T.grady]                                                       1.1058      0.235      4.705      0.000       0.645       1.566
# C(county)[T.grant]                                                      -5.9801      0.235    -25.444      0.000      -6.441      -5.519
# C(county)[T.greer]                                                      -5.7539      0.647     -8.896      0.000      -7.022      -4.486
# C(county)[T.harmon]                                                     -4.3897      0.706     -6.222      0.000      -5.773      -3.007
# C(county)[T.harper]                                                     -6.6746      0.836     -7.980      0.000      -8.314      -5.035
# C(county)[T.haskell]                                                    -1.2773      0.287     -4.456      0.000      -1.839      -0.716
# C(county)[T.hughes]                                                     -0.6440      0.127     -5.070      0.000      -0.893      -0.395
# C(county)[T.jackson]                                                     3.3213      0.776      4.279      0.000       1.800       4.842
# C(county)[T.jefferson]                                                  -1.1757      0.376     -3.130      0.002      -1.912      -0.440
# C(county)[T.johnston]                                                   -0.5362      0.392     -1.368      0.171      -1.304       0.232
# C(county)[T.kay]                                                         5.9494      0.405     14.690      0.000       5.156       6.743
# C(county)[T.kingfisher]                                                 -1.1258      0.173     -6.525      0.000      -1.464      -0.788
# C(county)[T.kiowa]                                                       2.1550      0.476      4.528      0.000       1.222       3.088
# C(county)[T.latimer]                                                    -1.6501      0.496     -3.328      0.001      -2.622      -0.678
# C(county)[T.le flore]                                                   -0.3641      0.308     -1.182      0.237      -0.968       0.240
# C(county)[T.lincoln]                                                     0.1638      0.124      1.317      0.188      -0.080       0.408
# C(county)[T.logan]                                                       0.2655      0.264      1.004      0.315      -0.253       0.784
# C(county)[T.love]                                                       -0.8955      0.246     -3.645      0.000      -1.377      -0.414
# C(county)[T.major]                                                      -5.7986      0.253    -22.965      0.000      -6.293      -5.304
# C(county)[T.marshall]                                                   -0.4951      0.287     -1.728      0.084      -1.057       0.067
# C(county)[T.mayes]                                                       0.7413      0.133      5.571      0.000       0.480       1.002
# C(county)[T.mcclain]                                                     1.1657      0.318      3.663      0.000       0.542       1.789
# C(county)[T.mccurtain]                                                   8.7278      1.462      5.969      0.000       5.862      11.594
# C(county)[T.mcintosh]                                                   -0.5061      0.091     -5.575      0.000      -0.684      -0.328
# C(county)[T.murray]                                                     -0.6464      0.094     -6.859      0.000      -0.831      -0.462
# C(county)[T.muskogee]                                                    3.8738      0.188     20.630      0.000       3.506       4.242
# C(county)[T.noble]                                                       0.0004      0.169      0.002      0.998      -0.331       0.332
# C(county)[T.nowata]                                                      0.3909      0.204      1.919      0.055      -0.008       0.790
# C(county)[T.okfuskee]                                                    2.1046      0.119     17.759      0.000       1.872       2.337
# C(county)[T.oklahoma]                                                    7.8848      0.575     13.710      0.000       6.758       9.012
# C(county)[T.okmulgee]                                                    2.5829      0.151     17.124      0.000       2.287       2.878
# C(county)[T.osage]                                                      -1.1196      0.227     -4.932      0.000      -1.565      -0.675
# C(county)[T.ottawa]                                                      6.2630      0.611     10.247      0.000       5.065       7.461
# C(county)[T.pawnee]                                                      0.5568      0.208      2.681      0.007       0.150       0.964
# C(county)[T.payne]                                                       1.2103      0.262      4.614      0.000       0.696       1.724
# C(county)[T.pittsburg]                                                   1.8900      0.350      5.400      0.000       1.204       2.576
# C(county)[T.pontotoc]                                                    3.0423      0.094     32.219      0.000       2.857       3.227
# C(county)[T.pottawatomie]                                                3.7605      0.208     18.039      0.000       3.352       4.169
# C(county)[T.pushmataha]                                                 -1.3751      0.657     -2.094      0.036      -2.662      -0.088
# C(county)[T.roger mills]                                                -2.1115      0.691     -3.057      0.002      -3.465      -0.758
# C(county)[T.rogers]                                                      3.9138      0.279     14.025      0.000       3.367       4.461
# C(county)[T.seminole]                                                    2.5310      0.111     22.718      0.000       2.313       2.749
# C(county)[T.sequoyah]                                                    0.6378      0.202      3.158      0.002       0.242       1.034
# C(county)[T.stephens]                                                    2.5821      0.222     11.627      0.000       2.147       3.017
# C(county)[T.texas]                                                       2.1923      1.193      1.837      0.066      -0.147       4.531
# C(county)[T.tillman]                                                    -1.6429      0.467     -3.518      0.000      -2.558      -0.728
# C(county)[T.tulsa]                                                       8.8923      0.603     14.757      0.000       7.711      10.073
# C(county)[T.wagoner]                                                     3.7521      0.324     11.573      0.000       3.117       4.388
# C(county)[T.washington]                                                  4.6595      0.196     23.713      0.000       4.274       5.045
# C(county)[T.washita]                                                    -1.1059      0.361     -3.064      0.002      -1.813      -0.398
# C(county)[T.woods]                                                      -4.8475      0.509     -9.517      0.000      -5.846      -3.849
# C(county)[T.woodward]                                                   -0.6752      0.498     -1.355      0.175      -1.652       0.301
# C(year_cat)[T.2011]                                                      0.1841      0.666      0.276      0.782      -1.122       1.490
# C(year_cat)[T.2012]                                                      0.5224      0.418      1.249      0.211      -0.297       1.342
# C(year_cat)[T.2013]                                                      0.0475      0.389      0.122      0.903      -0.716       0.811
# C(year_cat)[T.2014]                                                      0.4999      0.394      1.269      0.204      -0.272       1.272
# C(year_cat)[T.2015]                                                      0.5636      0.494      1.141      0.254      -0.404       1.531
# C(year_cat)[T.2016]                                                      0.0270      0.448      0.060      0.952      -0.851       0.904
# C(year_cat)[T.2017]                                                     -0.0887      0.478     -0.186      0.853      -1.026       0.848
# C(year_cat)[T.2018]                                                     -0.4669      0.439     -1.064      0.287      -1.327       0.393
# C(year_cat)[T.2019]                                                     -0.5936      0.425     -1.396      0.163      -1.427       0.240
# C(year_cat)[T.2020]                                                     -1.1560      0.402     -2.877      0.004      -1.944      -0.368
# C(year_cat)[T.2021]                                                     -0.8537      0.511     -1.670      0.095      -1.855       0.148
# C(year_cat)[T.2022]                                                     -0.0309      0.389     -0.079      0.937      -0.794       0.732
# C(year_cat)[T.2023]                                                     -0.3246      0.514     -0.631      0.528      -1.332       0.683
# C(year_cat)[T.2024]                                                      0.0563      0.493      0.114      0.909      -0.910       1.022
# dist_mean                                                                0.0394      0.009      4.523      0.000       0.022       0.056
# dist_mean:race[T.Black or African American]                             -0.0213      0.018     -1.176      0.240      -0.057       0.014
# dist_mean:race[T.Asian]                                                 -0.0451      0.025     -1.775      0.076      -0.095       0.005
# dist_mean:race[T.American Indian or Alaska Native]                      -0.0493      0.014     -3.564      0.000      -0.076      -0.022
# dist_mean:race[T.More than one race]                                    -0.0659      0.008     -8.697      0.000      -0.081      -0.051
# dist_mean:race[T.Native Hawaiian or Other Pacific Islander]              0.0659      0.085      0.776      0.437      -0.101       0.232
# post_ban                                                                -0.2991      1.145     -0.261      0.794      -2.543       1.945
# post_ban:race[T.Black or African American]                              -0.7465      1.718     -0.435      0.664      -4.113       2.620
# post_ban:race[T.Asian]                                                   5.5970      3.193      1.753      0.080      -0.661      11.855
# post_ban:race[T.American Indian or Alaska Native]                       -5.9477      1.694     -3.512      0.000      -9.267      -2.628
# post_ban:race[T.More than one race]                                     -1.7591      2.098     -0.839      0.402      -5.870       2.352
# post_ban:race[T.Native Hawaiian or Other Pacific Islander]              15.8323      8.404      1.884      0.060      -0.639      32.304
# dist_mean:post_ban                                                      -0.0247      0.007     -3.327      0.001      -0.039      -0.010
# dist_mean:post_ban:race[T.Black or African American]                     0.0112      0.016      0.690      0.490      -0.021       0.043
# dist_mean:post_ban:race[T.Asian]                                         0.0007      0.028      0.025      0.980      -0.055       0.056
# dist_mean:post_ban:race[T.American Indian or Alaska Native]              0.0514      0.014      3.656      0.000       0.024       0.079
# dist_mean:post_ban:race[T.More than one race]                            0.0595      0.012      4.867      0.000       0.036       0.083
# dist_mean:post_ban:race[T.Native Hawaiian or Other Pacific Islander]    -0.1362      0.065     -2.092      0.036      -0.264      -0.009
# ==============================================================================
# Omnibus:                     4879.798   Durbin-Watson:                   2.280
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1001386.208
# Skew:                           3.729   Prob(JB):                         0.00
# Kurtosis:                      69.639   Cond. No.                     2.25e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 2.67e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /opt/anaconda3/lib/python3.13/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 113, but rank is 36
#   warnings.warn('covariance of constraints does not have full '

# %%
births_by_age = pd.read_csv("../data/output/oklahoma_births-by-county_by-age_2010-2024.csv")

births_by_age['county'] = births_by_age['county'].str.lower()
births_by_age_merged = births_by_age.merge(
    dist_year[["year", "county", "dist_mean"]],
    on=["year", "county"],
    how="left"
)
births_by_age_merged = births_by_age_merged[births_by_age_merged['county'] != 'unknown']

# %%
births_by_age_merged = births_by_age_merged[~births_by_age_merged['age'].isin(['Unknown Age'])]

reg_df = births_by_age_merged.dropna(subset=["birth_rate", "dist_mean"]).copy()
reg_df["post_ban"] = (reg_df["year"] >= 2022).astype("int64")
reg_df["year_cat"] = reg_df["year"].astype(str)
reg_df["dist_mean"] = reg_df["dist_mean"].astype("float64")
reg_df["birth_rate"] = reg_df["birth_rate"].astype("float64")

reg_df['age'] = reg_df['age'].astype('category')
reg_df['age'] = reg_df['age'].cat.reorder_categories(
    ['25-29 years', '10-14 years','15-17 years', '18-19 years', 
      '20-24 years', '30-34 years', '35-39 years', '40-44 years', '45-54 years',
    ],  # put your desired baseline first
    ordered=False
)

formula = "birth_rate ~ dist_mean * post_ban * age + C(county) + C(year_cat)"

model_fe_age = smf.ols(
    formula=formula,
    data=reg_df
).fit(
    cov_type="cluster",
    cov_kwds={"groups": reg_df["county"]}
)

print(model_fe_age.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             birth_rate   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                 1.422e+05
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):          2.22e-172
# Time:                        14:52:13   Log-Likelihood:                -32346.
# No. Observations:                8384   AIC:                         6.494e+04
# Df Residuals:                    8259   BIC:                         6.582e+04
# Df Model:                         124
# Covariance Type:              cluster
# =========================================================================================================
#                                             coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                67.9955      1.539     44.195      0.000      64.980      71.011
# age[T.10-14 years]                      -56.4874      1.935    -29.196      0.000     -60.279     -52.695
# age[T.15-17 years]                      -50.6471      2.020    -25.075      0.000     -54.606     -46.688
# age[T.18-19 years]                      -20.9050      3.745     -5.582      0.000     -28.246     -13.564
# age[T.20-24 years]                        1.1353      3.195      0.355      0.722      -5.126       7.397
# age[T.30-34 years]                      -19.1636      1.890    -10.139      0.000     -22.868     -15.459
# age[T.35-39 years]                      -41.5501      2.230    -18.635      0.000     -45.920     -37.180
# age[T.40-44 years]                      -54.9224      1.794    -30.613      0.000     -58.439     -51.406
# age[T.45-54 years]                      -55.2090      2.182    -25.305      0.000     -59.485     -50.933
# C(county)[T.alfalfa]                    -12.1994      0.232    -52.514      0.000     -12.655     -11.744
# C(county)[T.atoka]                       -8.6780      0.268    -32.375      0.000      -9.203      -8.153
# C(county)[T.beaver]                     -12.0819      0.764    -15.811      0.000     -13.580     -10.584
# C(county)[T.beckham]                     -6.7402      0.284    -23.768      0.000      -7.296      -6.184
# C(county)[T.blaine]                       2.4425      0.090     27.248      0.000       2.267       2.618
# C(county)[T.bryan]                       -7.9740      0.144    -55.318      0.000      -8.257      -7.691
# C(county)[T.caddo]                       -5.4807      0.032   -173.410      0.000      -5.543      -5.419
# C(county)[T.canadian]                    -8.6859      0.231    -37.559      0.000      -9.139      -8.233
# C(county)[T.carter]                      -3.0339      0.088    -34.583      0.000      -3.206      -2.862
# C(county)[T.cherokee]                   -12.1653      0.044   -276.034      0.000     -12.252     -12.079
# C(county)[T.choctaw]                      0.6721      0.341      1.971      0.049       0.004       1.341
# C(county)[T.cimarron]                   -11.1090      0.888    -12.504      0.000     -12.850      -9.368
# C(county)[T.cleveland]                  -16.1152      0.289    -55.817      0.000     -16.681     -15.549
# C(county)[T.coal]                        -3.7386      0.226    -16.525      0.000      -4.182      -3.295
# C(county)[T.comanche]                   -10.3927      0.091   -114.707      0.000     -10.570     -10.215
# C(county)[T.cotton]                      -9.5772      0.228    -42.073      0.000     -10.023      -9.131
# C(county)[T.craig]                       -8.2753      0.076   -108.974      0.000      -8.424      -8.127
# C(county)[T.creek]                       -6.0481      0.203    -29.796      0.000      -6.446      -5.650
# C(county)[T.custer]                      -9.8591      0.119    -82.722      0.000     -10.093      -9.625
# C(county)[T.delaware]                    -6.8340      0.059   -115.507      0.000      -6.950      -6.718
# C(county)[T.dewey]                       -6.2007      0.278    -22.270      0.000      -6.746      -5.655
# C(county)[T.ellis]                       -9.4049      0.512    -18.383      0.000     -10.408      -8.402
# C(county)[T.garfield]                    -3.9892      0.132    -30.122      0.000      -4.249      -3.730
# C(county)[T.garvin]                      -2.6935      0.106    -25.304      0.000      -2.902      -2.485
# C(county)[T.grady]                       -9.5042      0.144    -66.059      0.000      -9.786      -9.222
# C(county)[T.grant]                      -10.4223      0.208    -50.184      0.000     -10.829     -10.015
# C(county)[T.greer]                      -17.3913      0.459    -37.886      0.000     -18.291     -16.492
# C(county)[T.harmon]                      -8.9183      0.543    -16.413      0.000      -9.983      -7.853
# C(county)[T.harper]                      -8.3977      0.530    -15.858      0.000      -9.436      -7.360
# C(county)[T.haskell]                     -5.0578      0.174    -29.145      0.000      -5.398      -4.718
# C(county)[T.hughes]                      -9.2635      0.060   -153.470      0.000      -9.382      -9.145
# C(county)[T.jackson]                     -4.9807      0.324    -15.386      0.000      -5.615      -4.346
# C(county)[T.jefferson]                   -6.1518      0.249    -24.728      0.000      -6.639      -5.664
# C(county)[T.johnston]                    -8.9634      0.267    -33.611      0.000      -9.486      -8.441
# C(county)[T.kay]                         -3.6785      0.164    -22.389      0.000      -4.001      -3.356
# C(county)[T.kingfisher]                  -6.1322      0.141    -43.597      0.000      -6.408      -5.857
# C(county)[T.kiowa]                       -4.5701      0.331    -13.809      0.000      -5.219      -3.921
# C(county)[T.latimer]                    -10.5448      0.331    -31.818      0.000     -11.194      -9.895
# C(county)[T.le flore]                    -5.0238      0.200    -25.111      0.000      -5.416      -4.632
# C(county)[T.lincoln]                     -7.0395      0.096    -73.524      0.000      -7.227      -6.852
# C(county)[T.logan]                      -10.6055      0.217    -48.953      0.000     -11.030     -10.181
# C(county)[T.love]                        -4.4962      0.161    -27.859      0.000      -4.813      -4.180
# C(county)[T.major]                       -3.0719      0.163    -18.872      0.000      -3.391      -2.753
# C(county)[T.marshall]                    -3.2073      0.189    -16.972      0.000      -3.578      -2.837
# C(county)[T.mayes]                       -5.7766      0.091    -63.146      0.000      -5.956      -5.597
# C(county)[T.mcclain]                     -8.1101      0.232    -34.887      0.000      -8.566      -7.654
# C(county)[T.mccurtain]                   -0.7555      0.497     -1.521      0.128      -1.729       0.218
# C(county)[T.mcintosh]                    -5.0484      0.059    -85.549      0.000      -5.164      -4.933
# C(county)[T.murray]                      -5.8792      0.052   -112.902      0.000      -5.981      -5.777
# C(county)[T.muskogee]                    -6.2513      0.071    -88.565      0.000      -6.390      -6.113
# C(county)[T.noble]                       -8.0855      0.169    -47.921      0.000      -8.416      -7.755
# C(county)[T.nowata]                      -6.5764      0.157    -42.001      0.000      -6.883      -6.270
# C(county)[T.okfuskee]                    -4.7584      0.061    -78.191      0.000      -4.878      -4.639
# C(county)[T.oklahoma]                    -5.6764      0.319    -17.801      0.000      -6.301      -5.051
# C(county)[T.okmulgee]                    -7.1610      0.107    -67.102      0.000      -7.370      -6.952
# C(county)[T.osage]                      -12.4401      0.145    -85.621      0.000     -12.725     -12.155
# C(county)[T.ottawa]                      -4.3238      0.099    -43.583      0.000      -4.518      -4.129
# C(county)[T.pawnee]                      -5.0458      0.165    -30.555      0.000      -5.369      -4.722
# C(county)[T.payne]                      -17.3753      0.136   -128.206      0.000     -17.641     -17.110
# C(county)[T.pittsburg]                   -7.5594      0.173    -43.731      0.000      -7.898      -7.221
# C(county)[T.pontotoc]                    -8.3124      0.056   -148.840      0.000      -8.422      -8.203
# C(county)[T.pottawatomie]                -8.2621      0.141    -58.546      0.000      -8.539      -7.985
# C(county)[T.pushmataha]                  -6.2757      0.437    -14.344      0.000      -7.133      -5.418
# C(county)[T.roger mills]                 -6.7608      0.395    -17.135      0.000      -7.534      -5.987
# C(county)[T.rogers]                      -9.7636      0.185    -52.909      0.000     -10.125      -9.402
# C(county)[T.seminole]                    -4.0550      0.053    -75.807      0.000      -4.160      -3.950
# C(county)[T.sequoyah]                    -4.2699      0.125    -34.102      0.000      -4.515      -4.025
# C(county)[T.stephens]                    -5.4946      0.056    -97.632      0.000      -5.605      -5.384
# C(county)[T.texas]                       -3.8070      0.746     -5.100      0.000      -5.270      -2.344
# C(county)[T.tillman]                     -9.7713      0.321    -30.426      0.000     -10.401      -9.142
# C(county)[T.tulsa]                       -6.5547      0.325    -20.146      0.000      -7.192      -5.917
# C(county)[T.wagoner]                     -9.5095      0.199    -47.718      0.000      -9.900      -9.119
# C(county)[T.washington]                  -6.8804      0.167    -41.186      0.000      -7.208      -6.553
# C(county)[T.washita]                     -4.9100      0.218    -22.537      0.000      -5.337      -4.483
# C(county)[T.woods]                      -18.5105      0.314    -59.041      0.000     -19.125     -17.896
# C(county)[T.woodward]                    -5.8497      0.333    -17.568      0.000      -6.502      -5.197
# C(year_cat)[T.2011]                      -1.3866      0.606     -2.290      0.022      -2.573      -0.200
# C(year_cat)[T.2012]                      -1.1271      0.592     -1.903      0.057      -2.288       0.034
# C(year_cat)[T.2013]                      -0.9485      0.538     -1.764      0.078      -2.003       0.106
# C(year_cat)[T.2014]                      -2.3039      0.556     -4.142      0.000      -3.394      -1.214
# C(year_cat)[T.2015]                      -2.0723      0.634     -3.266      0.001      -3.316      -0.829
# C(year_cat)[T.2016]                      -3.7495      0.511     -7.336      0.000      -4.751      -2.748
# C(year_cat)[T.2017]                      -4.7043      0.530     -8.884      0.000      -5.742      -3.666
# C(year_cat)[T.2018]                      -4.7166      0.526     -8.968      0.000      -5.747      -3.686
# C(year_cat)[T.2019]                      -5.5338      0.549    -10.087      0.000      -6.609      -4.459
# C(year_cat)[T.2020]                      -6.8850      0.674    -10.215      0.000      -8.206      -5.564
# C(year_cat)[T.2021]                      -5.3342      0.577     -9.248      0.000      -6.465      -4.204
# C(year_cat)[T.2022]                       0.1604      0.822      0.195      0.845      -1.451       1.771
# C(year_cat)[T.2023]                      -1.0749      1.054     -1.020      0.308      -3.140       0.990
# C(year_cat)[T.2024]                      -1.3590      0.927     -1.466      0.143      -3.176       0.458
# dist_mean                                 0.0640      0.021      3.123      0.002       0.024       0.104
# dist_mean:age[T.10-14 years]             -0.0848      0.024     -3.597      0.000      -0.131      -0.039
# dist_mean:age[T.15-17 years]             -0.0695      0.025     -2.768      0.006      -0.119      -0.020
# dist_mean:age[T.18-19 years]             -0.0809      0.047     -1.725      0.084      -0.173       0.011
# dist_mean:age[T.20-24 years]              0.0114      0.034      0.334      0.738      -0.056       0.078
# dist_mean:age[T.30-34 years]             -0.0781      0.020     -3.928      0.000      -0.117      -0.039
# dist_mean:age[T.35-39 years]             -0.1013      0.028     -3.623      0.000      -0.156      -0.046
# dist_mean:age[T.40-44 years]             -0.0762      0.021     -3.565      0.000      -0.118      -0.034
# dist_mean:age[T.45-54 years]             -0.0884      0.024     -3.625      0.000      -0.136      -0.041
# post_ban                                 -2.2735      2.680     -0.848      0.396      -7.525       2.978
# post_ban:age[T.10-14 years]              -0.6321      3.296     -0.192      0.848      -7.092       5.828
# post_ban:age[T.15-17 years]              -2.9169      3.619     -0.806      0.420     -10.010       4.177
# post_ban:age[T.18-19 years]             -25.3004      5.036     -5.024      0.000     -35.171     -15.430
# post_ban:age[T.20-24 years]             -23.8027      4.779     -4.980      0.000     -33.170     -14.435
# post_ban:age[T.30-34 years]               3.0182      4.046      0.746      0.456      -4.912      10.949
# post_ban:age[T.35-39 years]               4.2728      3.765      1.135      0.256      -3.106      11.652
# post_ban:age[T.40-44 years]               1.4665      3.496      0.420      0.675      -5.385       8.318
# post_ban:age[T.45-54 years]               1.3980      3.851      0.363      0.717      -6.150       8.946
# dist_mean:post_ban                       -0.0432      0.022     -1.984      0.047      -0.086      -0.001
# dist_mean:post_ban:age[T.10-14 years]     0.0600      0.023      2.611      0.009       0.015       0.105
# dist_mean:post_ban:age[T.15-17 years]     0.0407      0.025      1.610      0.107      -0.009       0.090
# dist_mean:post_ban:age[T.18-19 years]     0.1154      0.044      2.617      0.009       0.029       0.202
# dist_mean:post_ban:age[T.20-24 years]     0.0585      0.033      1.784      0.074      -0.006       0.123
# dist_mean:post_ban:age[T.30-34 years]     0.0444      0.024      1.839      0.066      -0.003       0.092
# dist_mean:post_ban:age[T.35-39 years]     0.0526      0.027      1.980      0.048       0.001       0.105
# dist_mean:post_ban:age[T.40-44 years]     0.0441      0.022      1.980      0.048       0.000       0.088
# dist_mean:post_ban:age[T.45-54 years]     0.0484      0.026      1.866      0.062      -0.002       0.099
# ==============================================================================
# Omnibus:                     1040.609   Durbin-Watson:                   1.676
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7689.394
# Skew:                           0.357   Prob(JB):                         0.00
# Kurtosis:                       7.637   Cond. No.                     2.25e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 4.2e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /opt/anaconda3/lib/python3.13/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 125, but rank is 48
#   warnings.warn('covariance of constraints does not have full '

# %%
births_by_edu = pd.read_csv('../data/output/oklahoma_births_by-mothers-edu_w-pop_2010-2024.csv')
births_by_edu['county'] = births_by_edu['county'].str.lower()
births_by_edu_merged = births_by_edu.merge(
    dist_year[["year", "county", "dist_mean"]],
    on=["year", "county"],
    how="left"
)
births_by_edu_merged = births_by_edu_merged[births_by_edu_merged['county'] != 'unknown']

# %%
births_by_edu_merged
# Out:
#       year    county      education  live_births  percent_live_births  \
# 0     2010     adair    0 - 8 years         10.0                 2.70
# 1     2010     adair       12 years         91.0                24.30
# 2     2010     adair  13 - 15 years         78.0                20.90
# 3     2010     adair   9 - 11 years        164.0                43.90
# 4     2010     adair    >= 16 years         31.0                 8.30
# ...    ...       ...            ...          ...                  ...
# 5770  2024  woodward    0 - 8 years          0.0                 0.00
# 5771  2024  woodward       12 years         96.0                35.50
# 5772  2024  woodward  13 - 15 years         71.0                30.15
# 5773  2024  woodward   9 - 11 years         38.0                14.90
# 5774  2024  woodward    >= 16 years         50.0                10.80
#
#       acs_window    GEOID  population  live_births_per_1000   dist_mean
# 0           2013  40001.0      1137.0              8.795075   41.352927
# 1           2013  40001.0      5766.0             15.782171   41.352927
# 2           2013  40001.0      2989.0             26.095684   41.352927
# 3           2013  40001.0      2098.0             78.169685   41.352927
# 4           2013  40001.0      1816.0             17.070485   41.352927
# ...          ...      ...         ...                   ...         ...
# 5770        2023  40153.0       362.0              0.000000  209.295210
# 5771        2023  40153.0      5226.0             18.369690  209.295210
# 5772        2023  40153.0         NaN                   NaN  209.295210
# 5773        2023  40153.0      1286.0             29.548989  209.295210
# 5774        2023  40153.0      2961.0             16.886187  209.295210
#
# [5775 rows x 10 columns]

# %%
births_by_edu_merged = births_by_edu_merged[~births_by_edu_merged['education'].isin(['UNKNOWN'])]

reg_df = births_by_edu_merged.dropna(subset=["live_births_per_1000"]).reset_index().copy()
reg_df["post_ban"] = (reg_df["year"] >= 2022).astype("int64")
reg_df["year_cat"] = reg_df["year"].astype(str)
reg_df["live_births_per_1000"] = reg_df["live_births_per_1000"].astype("float64")

reg_df['education'] = reg_df['education'].astype('category')
reg_df['education'] = reg_df['education'].cat.reorder_categories(
    ['>= 16 years', '0 - 8 years', '12 years',  '9 - 11 years', '13 - 15 years'],  # put your desired baseline first
    ordered=False
)

formula = "live_births_per_1000 ~ dist_mean * post_ban * education + C(county) + C(year_cat)"

model_fe_edu = smf.ols(
    formula=formula,
    data=reg_df
).fit(
    cov_type="cluster",
    cov_kwds={"groups": reg_df["county"]}
)

print(model_fe_edu.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     live_births_per_1000   R-squared:                       0.615
# Model:                              OLS   Adj. R-squared:                  0.607
# Method:                   Least Squares   F-statistic:                 3.877e+04
# Date:                  Wed, 03 Dec 2025   Prob (F-statistic):          4.56e-142
# Time:                          19:19:12   Log-Likelihood:                -17064.
# No. Observations:                  5106   AIC:                         3.434e+04
# Df Residuals:                      5002   BIC:                         3.502e+04
# Df Model:                           103
# Covariance Type:                cluster
# =================================================================================================================
#                                                     coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# Intercept                                        20.4920      1.251     16.387      0.000      18.041      22.943
# education[T.0 - 8 years]                         -7.9995      2.358     -3.392      0.001     -12.622      -3.377
# education[T.12 years]                             0.2958      1.156      0.256      0.798      -1.970       2.561
# education[T.9 - 11 years]                        13.2854      2.237      5.939      0.000       8.901      17.669
# education[T.13 - 15 years]                        8.3154      0.869      9.572      0.000       6.613      10.018
# C(county)[T.alfalfa]                            -12.0780      0.228    -52.901      0.000     -12.525     -11.630
# C(county)[T.atoka]                               -8.5367      0.295    -28.948      0.000      -9.115      -7.959
# C(county)[T.beaver]                              -8.6912      0.799    -10.881      0.000     -10.257      -7.126
# C(county)[T.beckham]                             -0.8925      0.322     -2.776      0.006      -1.523      -0.262
# C(county)[T.blaine]                              -4.2358      0.061    -69.690      0.000      -4.355      -4.117
# C(county)[T.bryan]                               -2.6145      0.167    -15.641      0.000      -2.942      -2.287
# C(county)[T.caddo]                               -3.4836      0.041    -85.290      0.000      -3.564      -3.404
# C(county)[T.canadian]                            -2.4432      0.199    -12.264      0.000      -2.834      -2.053
# C(county)[T.carter]                              -0.6327      0.112     -5.637      0.000      -0.853      -0.413
# C(county)[T.cherokee]                            -1.0096      0.025    -40.608      0.000      -1.058      -0.961
# C(county)[T.choctaw]                             -5.3785      0.379    -14.189      0.000      -6.121      -4.636
# C(county)[T.cimarron]                           -10.5034      0.871    -12.057      0.000     -12.211      -8.796
# C(county)[T.cleveland]                           -4.2669      0.247    -17.305      0.000      -4.750      -3.784
# C(county)[T.coal]                                -3.1511      0.233    -13.542      0.000      -3.607      -2.695
# C(county)[T.comanche]                            -0.1802      0.103     -1.750      0.080      -0.382       0.022
# C(county)[T.cotton]                              -8.7052      0.235    -37.003      0.000      -9.166      -8.244
# C(county)[T.craig]                               -6.8759      0.043   -159.847      0.000      -6.960      -6.792
# C(county)[T.creek]                               -3.7660      0.178    -21.153      0.000      -4.115      -3.417
# C(county)[T.custer]                               3.2197      0.150     21.458      0.000       2.926       3.514
# C(county)[T.delaware]                            -7.1282      0.056   -128.034      0.000      -7.237      -7.019
# C(county)[T.dewey]                               -5.4595      0.295    -18.538      0.000      -6.037      -4.882
# C(county)[T.ellis]                              -11.4124      0.490    -23.308      0.000     -12.372     -10.453
# C(county)[T.garfield]                             3.8726      0.114     33.941      0.000       3.649       4.096
# C(county)[T.garvin]                              -2.4885      0.089    -27.832      0.000      -2.664      -2.313
# C(county)[T.grady]                               -5.1309      0.124    -41.383      0.000      -5.374      -4.888
# C(county)[T.grant]                               -8.5148      0.125    -68.294      0.000      -8.759      -8.270
# C(county)[T.greer]                              -11.2352      0.479    -23.441      0.000     -12.175     -10.296
# C(county)[T.harmon]                              -7.5996      0.525    -14.477      0.000      -8.629      -6.571
# C(county)[T.harper]                              -7.5424      0.555    -13.582      0.000      -8.631      -6.454
# C(county)[T.haskell]                             -5.9269      0.198    -29.901      0.000      -6.315      -5.538
# C(county)[T.hughes]                              -8.1027      0.079   -102.135      0.000      -8.258      -7.947
# C(county)[T.jackson]                              3.6014      0.363      9.910      0.000       2.889       4.314
# C(county)[T.jefferson]                           -7.9747      0.253    -31.557      0.000      -8.470      -7.479
# C(county)[T.johnston]                            -6.5359      0.293    -22.329      0.000      -7.110      -5.962
# C(county)[T.kay]                                  0.7193      0.131      5.507      0.000       0.463       0.975
# C(county)[T.kingfisher]                          -1.4691      0.091    -16.183      0.000      -1.647      -1.291
# C(county)[T.kiowa]                               -6.6232      0.357    -18.563      0.000      -7.323      -5.924
# C(county)[T.latimer]                             -7.1399      0.358    -19.935      0.000      -7.842      -6.438
# C(county)[T.le flore]                            -1.6351      0.228     -7.176      0.000      -2.082      -1.189
# C(county)[T.lincoln]                             -6.3271      0.058   -108.650      0.000      -6.441      -6.213
# C(county)[T.logan]                               -5.1565      0.167    -30.858      0.000      -5.484      -4.829
# C(county)[T.love]                                -2.3860      0.177    -13.494      0.000      -2.733      -2.039
# C(county)[T.major]                                0.1795      0.181      0.989      0.323      -0.176       0.535
# C(county)[T.marshall]                            -4.8857      0.224    -21.806      0.000      -5.325      -4.447
# C(county)[T.mayes]                               -2.2553      0.071    -31.875      0.000      -2.394      -2.117
# C(county)[T.murray]                              -6.5400      0.035   -184.423      0.000      -6.610      -6.471
# C(county)[T.muskogee]                            -0.9324      0.045    -20.859      0.000      -1.020      -0.845
# C(county)[T.noble]                               -6.1743      0.094    -65.901      0.000      -6.358      -5.991
# C(county)[T.nowata]                              -5.9818      0.086    -69.456      0.000      -6.151      -5.813
# C(county)[T.okfuskee]                            -4.8813      0.045   -107.841      0.000      -4.970      -4.793
# C(county)[T.oklahoma]                             6.4183      0.253     25.364      0.000       5.922       6.914
# C(county)[T.okmulgee]                            -2.7793      0.084    -33.007      0.000      -2.944      -2.614
# C(county)[T.osage]                               -9.2643      0.113    -82.058      0.000      -9.486      -9.043
# C(county)[T.ottawa]                               1.3185      0.107     12.369      0.000       1.110       1.527
# C(county)[T.pawnee]                              -5.4316      0.113    -48.017      0.000      -5.653      -5.210
# C(county)[T.payne]                               -0.9190      0.077    -11.864      0.000      -1.071      -0.767
# C(county)[T.pittsburg]                           -5.6552      0.210    -26.994      0.000      -6.066      -5.245
# C(county)[T.pontotoc]                            -0.7644      0.077     -9.877      0.000      -0.916      -0.613
# C(county)[T.pottawatomie]                        -2.2244      0.105    -21.224      0.000      -2.430      -2.019
# C(county)[T.pushmataha]                          -8.6277      0.480    -17.967      0.000      -9.569      -7.687
# C(county)[T.roger mills]                         -2.9898      0.419     -7.139      0.000      -3.811      -2.169
# C(county)[T.rogers]                              -3.7429      0.165    -22.700      0.000      -4.066      -3.420
# C(county)[T.seminole]                            -2.5908      0.030    -86.633      0.000      -2.649      -2.532
# C(county)[T.sequoyah]                            -3.1270      0.149    -20.937      0.000      -3.420      -2.834
# C(county)[T.stephens]                            -5.0214      0.077    -65.525      0.000      -5.172      -4.871
# C(county)[T.texas]                                6.2076      0.867      7.159      0.000       4.508       7.907
# C(county)[T.tillman]                             -7.1387      0.355    -20.121      0.000      -7.834      -6.443
# C(county)[T.tulsa]                                7.3600      0.272     27.059      0.000       6.827       7.893
# C(county)[T.wagoner]                             -4.2739      0.179    -23.917      0.000      -4.624      -3.924
# C(county)[T.washington]                          -3.7067      0.112    -33.180      0.000      -3.926      -3.488
# C(county)[T.washita]                             -2.0238      0.251     -8.070      0.000      -2.515      -1.532
# C(county)[T.woods]                               -6.3791      0.357    -17.844      0.000      -7.080      -5.678
# C(county)[T.woodward]                             3.8895      0.391      9.943      0.000       3.123       4.656
# C(year_cat)[T.2011]                              -0.5855      0.404     -1.449      0.147      -1.378       0.207
# C(year_cat)[T.2012]                              -0.7334      0.377     -1.947      0.052      -1.472       0.005
# C(year_cat)[T.2013]                              -0.4287      0.518     -0.827      0.408      -1.445       0.587
# C(year_cat)[T.2014]                              -0.9212      0.504     -1.829      0.067      -1.909       0.066
# C(year_cat)[T.2015]                              -1.1377      0.535     -2.128      0.033      -2.186      -0.090
# C(year_cat)[T.2016]                              -1.8882      0.506     -3.728      0.000      -2.881      -0.896
# C(year_cat)[T.2017]                              -2.8642      0.509     -5.631      0.000      -3.861      -1.867
# C(year_cat)[T.2018]                              -3.0303      0.480     -6.307      0.000      -3.972      -2.089
# C(year_cat)[T.2019]                              -2.9877      0.555     -5.385      0.000      -4.075      -1.900
# C(year_cat)[T.2020]                              -3.7532      0.542     -6.923      0.000      -4.816      -2.691
# C(year_cat)[T.2021]                              -3.7442      0.501     -7.466      0.000      -4.727      -2.761
# C(year_cat)[T.2022]                               0.1423      0.521      0.273      0.785      -0.879       1.164
# C(year_cat)[T.2023]                              -0.4385      0.501     -0.876      0.381      -1.420       0.543
# C(year_cat)[T.2024]                              -0.9929      0.474     -2.095      0.036      -1.922      -0.064
# dist_mean                                         0.0131      0.015      0.902      0.367      -0.015       0.042
# dist_mean:education[T.0 - 8 years]               -0.0083      0.028     -0.296      0.767      -0.064       0.047
# dist_mean:education[T.12 years]                   0.0116      0.012      0.960      0.337      -0.012       0.035
# dist_mean:education[T.9 - 11 years]              -0.0024      0.023     -0.104      0.917      -0.047       0.042
# dist_mean:education[T.13 - 15 years]              0.0091      0.008      1.117      0.264      -0.007       0.025
# post_ban                                         -1.2890      1.233     -1.046      0.296      -3.705       1.127
# post_ban:education[T.0 - 8 years]                -1.1571      2.729     -0.424      0.672      -6.505       4.191
# post_ban:education[T.12 years]                   -4.7458      1.806     -2.628      0.009      -8.285      -1.206
# post_ban:education[T.9 - 11 years]               -7.2335      4.337     -1.668      0.095     -15.734       1.266
# post_ban:education[T.13 - 15 years]           -4.125e-13   4.91e-26  -8.41e+12      0.000   -4.12e-13   -4.12e-13
# dist_mean:post_ban                               -0.0097      0.013     -0.737      0.461      -0.036       0.016
# dist_mean:post_ban:education[T.0 - 8 years]       0.0049      0.025      0.196      0.844      -0.044       0.054
# dist_mean:post_ban:education[T.12 years]          0.0168      0.012      1.377      0.169      -0.007       0.041
# dist_mean:post_ban:education[T.9 - 11 years]     -0.0031      0.026     -0.118      0.906      -0.055       0.048
# dist_mean:post_ban:education[T.13 - 15 years]          0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                     1807.153   Durbin-Watson:                   2.219
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22766.071
# Skew:                           1.328   Prob(JB):                         0.00
# Kurtosis:                      12.998   Cond. No.                     1.71e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 4.38e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /opt/anaconda3/lib/python3.13/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 106, but rank is 30
#   warnings.warn('covariance of constraints does not have full '
